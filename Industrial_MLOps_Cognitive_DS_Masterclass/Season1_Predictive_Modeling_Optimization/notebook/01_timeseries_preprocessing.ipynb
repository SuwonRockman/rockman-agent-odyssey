# %% [markdown]
# # Phase 1: Industrial Time-Series Preprocessing
#
# 이 단계에서는 산업용 설비에서 수집된 시계열 센서 데이터를 정제하고 노이즈를 필터링하는 전처리 기법을 학습합니다.
#
# ## 실습 목표
# 1. 센서 데이터의 결측치 및 이상치 탐지 및 대체
# 2. 이동평균(Moving Average) 및 칼만 필터(Kalman Filter)를 활용한 센서 노이즈 감쇄
# 3. Rolling Window 기법을 활용한 시간 단위 데이터 다운샘플링

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import medfilt

print("Libraries loaded successfully.")

# %% [markdown]
# ## 1. 데이터 로드 및 이상치 탐지
# 가상의 센서 노이즈 데이터를 로드하고, 통계적 기법(Z-score, IQR)을 통해 이상치를 제거 및 대체해보세요.

# %%
# TODO: 가상 시계열 센서 데이터 생성 및 이상치 주입 실습 진행
