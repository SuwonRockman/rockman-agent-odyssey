# %% [markdown]
# # Phase 3: Equipment Failure Classification
#
# 이 단계에서는 피처로 가공된 설비 데이터를 기반으로 고장 종류(과열, 진동 장애, 툴 마모 등)를 예측하는 멀티클래스 분류 모델을 학습합니다.
#
# ## 실습 목표
# 1. XGBoost, LightGBM 모델의 기초 학습 및 성능 검증
# 2. F1-score, Confusion Matrix를 통한 정밀 평가
# 3. Optuna를 활용한 하이퍼파라미터 최적화 자동화

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import xgboost as xgb
import lightgbm as lgb
import optuna

print("Libraries loaded successfully.")

# %% [markdown]
# ## 1. 머신러닝 학습 파이프라인
# XGBoost 모델을 학습시키고, Confusion Matrix로 모델의 장단점을 파악하는 기본 루틴을 구축합니다.

# %%
# TODO: 설비 고장 원인 데이터 학습 및 최적화 진행
