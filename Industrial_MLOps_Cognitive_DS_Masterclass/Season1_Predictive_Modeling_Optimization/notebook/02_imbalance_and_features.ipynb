# %% [markdown]
# # Phase 2: Imbalanced Data & Feature Engineering
#
# 이 단계에서는 극도로 장애 데이터가 희소한 제조업 환경의 클래스 불균형 문제를 극복하기 위한 기법과 시계열 피처 추출 기법을 다룹니다.
#
# ## 실습 목표
# 1. SMOTE, ADASYN을 이용한 불균형 데이터셋 오버샘플링 구현
# 2. 시간 영역 통계 피처(Mean, Std, Skewness, Kurtosis) 생성
# 3. FFT (Fast Fourier Transform)를 이용한 주파수 영역 피처 변환

# %%
import numpy as np
import pandas as pd
from scipy.fft import fft
from sklearn.datasets import make_classification
# imblearn 라이브러리가 있을 경우 로드하여 테스트
try:
    from imblearn.over_sampling import SMOTE
    print("imblearn loaded successfully.")
except ImportError:
    print("Please install imbalanced-learn package for SMOTE.")

# %% [markdown]
# ## 1. SMOTE를 활용한 오버샘플링
# 극심한 불균형 데이터를 복원하고 결정 경계를 어떻게 채워나가는지 실습해 보세요.

# %%
# TODO: 불균형 모의 데이터 생성 및 SMOTE 오버샘플링 실습 진행
